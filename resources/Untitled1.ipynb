# %%
print("hellow world")
# Out:
# hellow world

# %%
import pandas as pd

# %%
df=pd.read_csv("call_activity.csv")
df
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 df=pd.read_csv("call_activity.csv")
#       2 df
#
# NameError: name 'pd' is not defined

# %%
import pandas as pd
df = pd.read_csv("call_activity.csv")

df
# Out:
#      State  Account length  Area code International plan Voice mail plan  \
# 0       KS             128        415                 No             Yes
# 1       OH             107        415                 No             Yes
# 2       NJ             137        415                 No              No
# 3       OH              84        408                Yes              No
# 4       OK              75        415                Yes              No
# ...    ...             ...        ...                ...             ...
# 3328    AZ             192        415                 No             Yes
# 3329    WV              68        415                 No              No
# 3330    RI              28        510                 No              No
# 3331    CT             184        510                Yes              No
# 3332    TN              74        415                 No             Yes
#
#       Number vmail messages  Total day minutes  Total day calls  \
# ...

# %%
df.head()
# Out:
#   State  Account length  Area code International plan Voice mail plan  \
# 0    KS             128        415                 No             Yes
# 1    OH             107        415                 No             Yes
# 2    NJ             137        415                 No              No
# 3    OH              84        408                Yes              No
# 4    OK              75        415                Yes              No
#
#    Number vmail messages  Total day minutes  Total day calls  \
# 0                     25              265.1            110.0
# 1                     26              161.6            123.0
# 2                      0              243.4            114.0
# 3                      0              299.4             71.0
# 4                      0              166.7            113.0
#
#    Total day charge  Total eve minutes  Total eve calls  Total eve charge  \
# 0             45.07              197.4             99.0             16.78
# ...

# %%
df.tail()
# Out:
#      State  Account length  Area code International plan Voice mail plan  \
# 3328    AZ             192        415                 No             Yes
# 3329    WV              68        415                 No              No
# 3330    RI              28        510                 No              No
# 3331    CT             184        510                Yes              No
# 3332    TN              74        415                 No             Yes
#
#       Number vmail messages  Total day minutes  Total day calls  \
# 3328                     36              156.2             77.0
# 3329                      0              231.1             57.0
# 3330                      0              180.8            109.0
# 3331                      0              213.8            105.0
# 3332                     25              234.4            113.0
#
#       Total day charge  Total eve minutes  Total eve calls  Total eve charge  \
# ...

# %%
df.tail(2)
# Out:
#      State  Account length  Area code International plan Voice mail plan  \
# 3331    CT             184        510                Yes              No
# 3332    TN              74        415                 No             Yes
#
#       Number vmail messages  Total day minutes  Total day calls  \
# 3331                      0              213.8            105.0
# 3332                     25              234.4            113.0
#
#       Total day charge  Total eve minutes  Total eve calls  Total eve charge  \
# 3331             36.35              159.6             84.0             13.57
# 3332             39.85              265.9             82.0             22.60
#
#       Total night minutes  Total night calls  Total night charge  \
# 3331                139.2              137.0                6.26
# 3332                241.4               77.0               10.86
#
#       Total intl minutes  Total intl calls  Total intl charge  \
# ...

# %%
type(df)
# Out:
# pandas.DataFrame

# %%
df['State']
# Out:
# 0       KS
# 1       OH
# 2       NJ
# 3       OH
# 4       OK
#         ..
# 3328    AZ
# 3329    WV
# 3330    RI
# 3331    CT
# 3332    TN
# Name: State, Length: 3333, dtype: str

# %%
df.head(2)['State']
# Out:
# 0    KS
# 1    OH
# Name: State, dtype: str

# %%
type(df['State'])
# Out:
# pandas.Series

# %% [markdown]
# ## create data frame from dictonaries

# %%
call_activity = [
    {
        "call_id": 1,
        "customer_name": "Rahul Sharma",
        "agent_name": "Amit",
        "call_duration_sec": 320,
        "call_type": "Incoming",
        "call_status": "Resolved",
        "call_date": "2026-02-20"
    },
    {
        "call_id": 2,
        "customer_name": "Priya Singh",
        "agent_name": "Neha",
        "call_duration_sec": 210,
        "call_type": "Outgoing",
        "call_status": "Pending",
        "call_date": "2026-02-21"
    },
    {
        "call_id": 3,
        "customer_name": "Arjun Kumar",
        "agent_name": "Vikas",
        "call_duration_sec": 450,
        "call_type": "Incoming",
        "call_status": "Escalated",
        "call_date": "2026-02-22"
    },
    {
        "call_id": 4,
        "customer_name": "Sneha Reddy",
        "agent_name": "Amit",
        "call_duration_sec": 180,
        "call_type": "Missed",
        "call_status": "Unresolved",
        "call_date": "2026-02-23"
    }
]
df_dict=pd.DataFrame.from_dict(call_activity )

# %%
df_dict
# Out:
#    call_id customer_name agent_name  call_duration_sec call_type call_status  \
# 0        1  Rahul Sharma       Amit                320  Incoming    Resolved
# 1        2   Priya Singh       Neha                210  Outgoing     Pending
# 2        3   Arjun Kumar      Vikas                450  Incoming   Escalated
# 3        4   Sneha Reddy       Amit                180    Missed  Unresolved
#
#     call_date
# 0  2026-02-20
# 1  2026-02-21
# 2  2026-02-22
# 3  2026-02-23

# %%
df_dict.head(1)
# Out:
#    call_id customer_name agent_name  call_duration_sec call_type call_status  \
# 0        1  Rahul Sharma       Amit                320  Incoming    Resolved
#
#     call_date
# 0  2026-02-20

# %%
df_dict.columns
# Out:
# Index(['call_id', 'customer_name', 'agent_name', 'call_duration_sec',
#        'call_type', 'call_status', 'call_date'],
#       dtype='str')

# %%
df_dict.dtypes
# Out:
# call_id              int64
# customer_name          str
# agent_name             str
# call_duration_sec    int64
# call_type              str
# call_status            str
# call_date              str
# dtype: object

# %%
df_dict.State
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_2968\2924390106.py in ?()
# ----> 1 df_dict.State
#
# ~\miniconda3\envs\stockenv\Lib\site-packages\pandas\core\generic.py in ?(self, name)
#    6202             and name not in self._accessors
#    6203             and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    6204         ):
#    6205             return self[name]
# -> 6206         return object.__getattribute__(self, name)
#
# AttributeError: 'DataFrame' object has no attribute 'State'

# %%
df_dict.call_id
# Out:
# 0    1
# 1    2
# 2    3
# 3    4
# Name: call_id, dtype: int64

# %%
df_dict.call_id.unique()
# Out:
# array([1, 2, 3, 4])

# %%
df
# Out:
#      State  Account length  Area code International plan Voice mail plan  \
# 0       KS             128        415                 No             Yes
# 1       OH             107        415                 No             Yes
# 2       NJ             137        415                 No              No
# 3       OH              84        408                Yes              No
# 4       OK              75        415                Yes              No
# ...    ...             ...        ...                ...             ...
# 3328    AZ             192        415                 No             Yes
# 3329    WV              68        415                 No              No
# 3330    RI              28        510                 No              No
# 3331    CT             184        510                Yes              No
# 3332    TN              74        415                 No             Yes
#
#       Number vmail messages  Total day minutes  Total day calls  \
# ...

# %%
df[df['international plan']=='Yes']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\miniconda3\envs\stockenv\Lib\site-packages\pandas\core\indexes\base.py:3641, in Index.get_loc(self, key)
#    3640 try:
# -> 3641     return self._engine.get_loc(casted_key)
#    3642 except KeyError as err:
#
# File pandas/_libs/index.pyx:168, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/index.pyx:197, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:7668, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:7676, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'international plan'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[29], line 1
# ...

# %%
df[df['International plan'] == 'Yes']
# Out:
#      State  Account length  Area code International plan Voice mail plan  \
# 3       OH              84        408                Yes              No
# 4       OK              75        415                Yes              No
# 5       AL             118        510                Yes              No
# 7       MO             147        415                Yes              No
# 9       WV             141        415                Yes             Yes
# ...    ...             ...        ...                ...             ...
# 3304    IL              71        510                Yes              No
# 3309    VT             100        408                Yes              No
# 3317    SD             163        415                Yes              No
# 3320    GA             122        510                Yes              No
# 3331    CT             184        510                Yes              No
#
#       Number vmail messages  Total day minutes  Total day calls  \
# ...

# %%
df[(df['International plan'] == 'Yes') & (df['Churn'] == 'NO')]
# Out:
# Empty DataFrame
# Columns: [State, Account length, Area code, International plan, Voice mail plan, Number vmail messages, Total day minutes, Total day calls, Total day charge, Total eve minutes, Total eve calls, Total eve charge, Total night minutes, Total night calls, Total night charge, Total intl minutes, Total intl calls, Total intl charge, Customer service calls, Churn]
# Index: []

# %%
df
# Out:
#      State  Account length  Area code International plan Voice mail plan  \
# 0       KS             128        415                 No             Yes
# 1       OH             107        415                 No             Yes
# 2       NJ             137        415                 No              No
# 3       OH              84        408                Yes              No
# 4       OK              75        415                Yes              No
# ...    ...             ...        ...                ...             ...
# 3328    AZ             192        415                 No             Yes
# 3329    WV              68        415                 No              No
# 3330    RI              28        510                 No              No
# 3331    CT             184        510                Yes              No
# 3332    TN              74        415                 No             Yes
#
#       Number vmail messages  Total day minutes  Total day calls  \
# ...

# %%
df.iloc[2]
# Out:
# State                        NJ
# Account length              137
# Area code                   415
# International plan           No
# Voice mail plan              No
# Number vmail messages         0
# Total day minutes         243.4
# Total day calls           114.0
# Total day charge          41.38
# Total eve minutes         121.2
# Total eve calls           110.0
# Total eve charge           10.3
# Total night minutes       162.6
# Total night calls         104.0
# Total night charge         7.32
# Total intl minutes         12.2
# Total intl calls              5
# Total intl charge          3.29
# Customer service calls      0.0
# Churn                     False
# Name: 2, dtype: object

# %%
df.iloc[2]
# Out:
# State                        NJ
# Account length              137
# Area code                   415
# International plan           No
# Voice mail plan              No
# Number vmail messages         0
# Total day minutes         243.4
# Total day calls           114.0
# Total day charge          41.38
# Total eve minutes         121.2
# Total eve calls           110.0
# Total eve charge           10.3
# Total night minutes       162.6
# Total night calls         104.0
# Total night charge         7.32
# Total intl minutes         12.2
# Total intl calls              5
# Total intl charge          3.29
# Customer service calls      0.0
# Churn                     False
# Name: 2, dtype: object

# %%
df.iloc[0:5]
# Out:
#   State  Account length  Area code International plan Voice mail plan  \
# 0    KS             128        415                 No             Yes
# 1    OH             107        415                 No             Yes
# 2    NJ             137        415                 No              No
# 3    OH              84        408                Yes              No
# 4    OK              75        415                Yes              No
#
#    Number vmail messages  Total day minutes  Total day calls  \
# 0                     25              265.1            110.0
# 1                     26              161.6            123.0
# 2                      0              243.4            114.0
# 3                      0              299.4             71.0
# 4                      0              166.7            113.0
#
#    Total day charge  Total eve minutes  Total eve calls  Total eve charge  \
# 0             45.07              197.4             99.0             16.78
# ...

# %%
df.iloc[0:3, 0:2]
# Out:
#   State  Account length
# 0    KS             128
# 1    OH             107
# 2    NJ             137

# %%
df.iloc[-1]
# Out:
# State                        TN
# Account length               74
# Area code                   415
# International plan           No
# Voice mail plan             Yes
# Number vmail messages        25
# Total day minutes         234.4
# Total day calls           113.0
# Total day charge          39.85
# Total eve minutes         265.9
# Total eve calls            82.0
# Total eve charge           22.6
# Total night minutes       241.4
# Total night calls          77.0
# Total night charge        10.86
# Total intl minutes         13.7
# Total intl calls              4
# Total intl charge           3.7
# Customer service calls      0.0
# Churn                     False
# Name: 3332, dtype: object

# %%
df.isnull().sum()
# Out:
# State                      0
# Account length             0
# Area code                  0
# International plan         0
# Voice mail plan            0
# Number vmail messages      0
# Total day minutes         10
# Total day calls           10
# Total day charge          18
# Total eve minutes          9
# Total eve calls            8
# Total eve charge           0
# Total night minutes        0
# Total night calls          1
# Total night charge         0
# Total intl minutes         0
# Total intl calls           0
# Total intl charge          5
# Customer service calls     5
# Churn                      8
# dtype: int64

# %%
df
# Out:
#      State  Account length  Area code International plan Voice mail plan  \
# 0       KS             128        415                 No             Yes
# 1       OH             107        415                 No             Yes
# 2       NJ             137        415                 No              No
# 3       OH              84        408                Yes              No
# 4       OK              75        415                Yes              No
# ...    ...             ...        ...                ...             ...
# 3328    AZ             192        415                 No             Yes
# 3329    WV              68        415                 No              No
# 3330    RI              28        510                 No              No
# 3331    CT             184        510                Yes              No
# 3332    TN              74        415                 No             Yes
#
#       Number vmail messages  Total day minutes  Total day calls  \
# ...

# %%
df.iloc[0,3328]
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[42], line 1
# ----> 1 df.iloc[0,3328]
#
# File ~\miniconda3\envs\stockenv\Lib\site-packages\pandas\core\indexing.py:1199, in _LocationIndexer.__getitem__(self, key)
#    1197     key = tuple(com.apply_if_callable(x, self.obj) for x in key)
#    1198     if self._is_scalar_access(key):
# -> 1199         return self.obj._get_value(*key, takeable=self._takeable)
#    1200     return self._getitem_tuple(key)
#    1201 else:
#    1202     # we by definition only have the 0th axis
#
# File ~\miniconda3\envs\stockenv\Lib\site-packages\pandas\core\frame.py:4486, in DataFrame._get_value(self, index, col, takeable)
#    4467 """
#    4468 Quickly retrieve single value at passed column and index.
#    4469
#    (...)   4483 `self.columns._index_as_unique`; Caller is responsible for checking.
#    4484 """
#    4485 if takeable:
# ...

# %%
df.iloc[14,1]
# Out:
# np.int64(62)

# %%
df.iloc[1,12]
# Out:
# np.float64(254.4)

# %%
df.iloc[14]
# Out:
# State                        IA
# Account length               62
# Area code                   415
# International plan           No
# Voice mail plan              No
# Number vmail messages         0
# Total day minutes           NaN
# Total day calls             NaN
# Total day charge            NaN
# Total eve minutes         307.2
# Total eve calls            76.0
# Total eve charge          26.11
# Total night minutes       203.0
# Total night calls          99.0
# Total night charge         9.14
# Total intl minutes         13.1
# Total intl calls              6
# Total intl charge          3.54
# Customer service calls      4.0
# Churn                     False
# Name: 14, dtype: object

# %%
df.iloc[14]
# Out:
# State                        IA
# Account length               62
# Area code                   415
# International plan           No
# Voice mail plan              No
# Number vmail messages         0
# Total day minutes           NaN
# Total day calls             NaN
# Total day charge            NaN
# Total eve minutes         307.2
# Total eve calls            76.0
# Total eve charge          26.11
# Total night minutes       203.0
# Total night calls          99.0
# Total night charge         9.14
# Total intl minutes         13.1
# Total intl calls              6
# Total intl charge          3.54
# Customer service calls      4.0
# Churn                     False
# Name: 14, dtype: object

# %%
df.iloc[14,1]
# Out:
# np.int64(62)

# %%
df.iloc[14,2]
# Out:
# np.int64(415)

# %% [markdown]
# ## slicingmm mm mmm

# %%
df.slice(1:2)
# Out:
#   Cell In[51], line 1
#     df.slice(1:2)
#               ^
# SyntaxError: invalid syntax

# %%
df.iloc(2:4)
# Out:
#   Cell In[52], line 1
#     df.iloc(2:4)
#              ^
# SyntaxError: invalid syntax

# %%
df.iloc[1:9]
# Out:
#   State  Account length  Area code International plan Voice mail plan  \
# 1    OH             107        415                 No             Yes
# 2    NJ             137        415                 No              No
# 3    OH              84        408                Yes              No
# 4    OK              75        415                Yes              No
# 5    AL             118        510                Yes              No
# 6    MA             121        510                 No             Yes
# 7    MO             147        415                Yes              No
# 8    LA             117        408                 No              No
#
#    Number vmail messages  Total day minutes  Total day calls  \
# 1                     26              161.6            123.0
# 2                      0              243.4            114.0
# 3                      0              299.4             71.0
# 4                      0              166.7            113.0
# ...

# %%
state=df.copy()
state.set_index('State',inplace='True')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[54], line 2
#       1 state=df.copy()
# ----> 2 state.set_index('State',inplace='True')
#
# File ~\miniconda3\envs\stockenv\Lib\site-packages\pandas\core\frame.py:6946, in DataFrame.set_index(self, keys, drop, append, inplace, verify_integrity)
#    6943 else:
#    6944     verify_integrity = False
# -> 6946 inplace = validate_bool_kwarg(inplace, "inplace")
#    6947 self._check_inplace_and_allows_duplicate_labels(inplace)
#    6948 if not isinstance(keys, list):
#
# File ~\miniconda3\envs\stockenv\Lib\site-packages\pandas\util\_validators.py:266, in validate_bool_kwarg(value, arg_name, none_allowed, int_allowed)
#     263     good_value = good_value or isinstance(value, int)
#     265 if not good_value:
# --> 266     raise ValueError(
#     267         f'For argument "{arg_name}" expected type bool, received '
# ...

# %%
state = df.copy()
state.set_index('State', inplace=True)

# %%
state
# Out:
#        Account length  Area code International plan Voice mail plan  \
# State
# KS                128        415                 No             Yes
# OH                107        415                 No             Yes
# NJ                137        415                 No              No
# OH                 84        408                Yes              No
# OK                 75        415                Yes              No
# ...               ...        ...                ...             ...
# AZ                192        415                 No             Yes
# WV                 68        415                 No              No
# RI                 28        510                 No              No
# CT                184        510                Yes              No
# TN                 74        415                 No             Yes
#
#        Number vmail messages  Total day minutes  Total day calls  \
# State
# KS                        25              265.1            110.0
# ...

# %%
state.loc['NJ']
# Out:
#        Account length  Area code International plan Voice mail plan  \
# State
# NJ                137        415                 No              No
# NJ                149        408                 No              No
# NJ                138        408                 No              No
# NJ                128        415                 No              No
# NJ                 64        510                 No              No
# ...               ...        ...                ...             ...
# NJ                 75        415                 No             Yes
# NJ                108        415                 No              No
# NJ                107        408                 No             Yes
# NJ                 93        415                 No              No
# NJ                139        415                 No             Yes
#
#        Number vmail messages  Total day minutes  Total day calls  \
# State
# NJ                         0              243.4            114.0
# ...

# %%
df.reset_index()
# Out:
#       index State  Account length  Area code International plan  \
# 0         0    KS             128        415                 No
# 1         1    OH             107        415                 No
# 2         2    NJ             137        415                 No
# 3         3    OH              84        408                Yes
# 4         4    OK              75        415                Yes
# ...     ...   ...             ...        ...                ...
# 3328   3328    AZ             192        415                 No
# 3329   3329    WV              68        415                 No
# 3330   3330    RI              28        510                 No
# 3331   3331    CT             184        510                Yes
# 3332   3332    TN              74        415                 No
#
#      Voice mail plan  Number vmail messages  Total day minutes  \
# 0                Yes                     25              265.1
# 1                Yes                     26              161.6
# ...

# %%
mydataset = {
  'cars': ["BMW", "Volvo", "Ford"],
  'passings': [3, 7, 2]
}

myvar = pandas.DataFrame(mydataset)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[59], line 6
#       1 mydataset = {
#       2   'cars': ["BMW", "Volvo", "Ford"],
#       3   'passings': [3, 7, 2]
#       4 }
# ----> 6 myvar = pandas.DataFrame(mydataset)
#
# NameError: name 'pandas' is not defined

# %%
import pandas as pandas

# %%
mydataset = {
  'cars': ["BMW", "Volvo", "Ford"],
  'passings': [3, 7, 2]
}

myvar = pandas.DataFrame(mydataset)

# %%
myvar
# Out:
#     cars  passings
# 0    BMW         3
# 1  Volvo         7
# 2   Ford         2

# %%
myvar.drop('cars')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[64], line 1
# ----> 1 myvar.drop('cars')
#
# File ~\miniconda3\envs\stockenv\Lib\site-packages\pandas\core\frame.py:6288, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    6130 def drop(
#    6131     self,
#    6132     labels: IndexLabel | ListLike = None,
#    (...)   6139     errors: IgnoreRaise = "raise",
#    6140 ) -> DataFrame | None:
#    6141     """
#    6142     Drop specified labels from rows or columns.
#    6143
#    (...)   6286             weight  1.0     0.8
#    6287     """
# -> 6288     return super().drop(
#    6289         labels=labels,
#    6290         axis=axis,
#    6291         index=index,
#    6292         columns=columns,
#    6293         level=level,
#    6294         inplace=inplace,
#    6295         errors=errors,
#    6296     )
#
# ...

# %%
myvar.drop('cars',axis=1)
# Out:
#    passings
# 0         3
# 1         7
# 2         2

# %%
myvar['roll-no']=df['Area code']+2

# %%
df
# Out:
#      State  Account length  Area code International plan Voice mail plan  \
# 0       KS             128        415                 No             Yes
# 1       OH             107        415                 No             Yes
# 2       NJ             137        415                 No              No
# 3       OH              84        408                Yes              No
# 4       OK              75        415                Yes              No
# ...    ...             ...        ...                ...             ...
# 3328    AZ             192        415                 No             Yes
# 3329    WV              68        415                 No              No
# 3330    RI              28        510                 No              No
# 3331    CT             184        510                Yes              No
# 3332    TN              74        415                 No             Yes
#
#       Number vmail messages  Total day minutes  Total day calls  \
# ...

# %%
myvar
# Out:
#     cars  passings  roll-no
# 0    BMW         3      417
# 1  Volvo         7      417
# 2   Ford         2      417

# %%
myvar.to_csv("cars.csv", index=False)

# %%
myvar.to_json()
# Out:
# '{"cars":{"0":"BMW","1":"Volvo","2":"Ford"},"passings":{"0":3,"1":7,"2":2},"roll-no":{"0":417,"1":417,"2":417}}'
